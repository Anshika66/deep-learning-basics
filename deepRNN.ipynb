# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding  , SimpleRNN , Dense , Input , LSTM , GRU

# %%
#load the imdb dataset
(x_train, y_train) , (x_test , y_test) = imdb.load_data(num_words = 10000)

#pad sentences
x_train = pad_sequences(x_train , maxlen=100)
x_test  = pad_sequences(x_test , maxlen=100)

# %%
model = Sequential()

model.add(Input(shape=(100,)))
model.add(Embedding(10000 , 32))
model.add(SimpleRNN(5 , return_sequences=True))
model.add(SimpleRNN(5))
model.add(Dense(1 , activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 100, 5)         │           190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 320,251 (1.22 MB)
#  Trainable params: 320,251 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy' , optimizer='Adam' , metrics=['accuracy'])
model.fit(x_train , y_train ,epochs=5 ,validation_data=(x_test , y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.7301 - loss: 0.5391 - val_accuracy: 0.8115 - val_loss: 0.4344
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 48ms/step - accuracy: 0.8610 - loss: 0.3507 - val_accuracy: 0.7943 - val_loss: 0.4617
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.8918 - loss: 0.2857 - val_accuracy: 0.8248 - val_loss: 0.4178
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 49ms/step - accuracy: 0.9145 - loss: 0.2305 - val_accuracy: 0.8217 - val_loss: 0.4305
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.9317 - loss: 0.1936 - val_accuracy: 0.8164 - val_loss: 0.4518

# %%
model = Sequential()

model.add(Input(shape=(100,)))
model.add(Embedding(10000 , 32))
model.add(LSTM(5 , return_sequences=True))
model.add(LSTM(5))
model.add(Dense(1 , activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy' , optimizer='Adam' , metrics=['accuracy'])
model.fit(x_train , y_train ,epochs=5 ,validation_data=(x_test , y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 74ms/step - accuracy: 0.7094 - loss: 0.5592 - val_accuracy: 0.8388 - val_loss: 0.3816
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8806 - loss: 0.3040 - val_accuracy: 0.8458 - val_loss: 0.3526
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 73ms/step - accuracy: 0.9210 - loss: 0.2175 - val_accuracy: 0.8414 - val_loss: 0.3805
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 70ms/step - accuracy: 0.9469 - loss: 0.1577 - val_accuracy: 0.8396 - val_loss: 0.4263
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 71ms/step - accuracy: 0.9600 - loss: 0.1273 - val_accuracy: 0.8372 - val_loss: 0.4519

# %%
model = Sequential()

model.add(Input(shape=(100,)))
model.add(Embedding(10000 , 32))
model.add(GRU(5 , return_sequences=True))
model.add(GRU(5))
model.add(Dense(1 , activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy' , optimizer='Adam' , metrics=['accuracy'])
model.fit(x_train , y_train ,epochs=5 ,validation_data=(x_test , y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 103ms/step - accuracy: 0.6908 - loss: 0.5702 - val_accuracy: 0.8180 - val_loss: 0.4006
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.8938 - loss: 0.2754 - val_accuracy: 0.8436 - val_loss: 0.3617
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.9245 - loss: 0.2084 - val_accuracy: 0.8408 - val_loss: 0.3836
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 104ms/step - accuracy: 0.9476 - loss: 0.1557 - val_accuracy: 0.8398 - val_loss: 0.4002
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 97ms/step - accuracy: 0.9639 - loss: 0.1163 - val_accuracy: 0.8362 - val_loss: 0.4667
